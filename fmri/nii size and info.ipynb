# %%
import pydicom

# Specify the path to your DICOM file
dicom_file_path = r'E:\proje\data\1Heydari\fMRI\MR\Series 2-t1_mprage_sag_p2_iso/1.3.12.2.1107.5.2.43.66088.2019071009473824115600765.dcm'

# Load the DICOM file
dicom_dataset = pydicom.dcmread(dicom_file_path)

# Access the header information
header = dicom_dataset

# Print the header information
print(header)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 218
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.2.43.66088.2019071009473824115600765
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.6.0
# (0002, 0013) Implementation Version Name         SH: 'OFFIS_DCMTK_360'
# (0002, 0016) Source Application Entity Title     AE: 'MASTERGENTEST'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM']
# (0008, 0012) Instance Creation Date              DA: '20190710'
# ...

# %%
import pydicom

# Specify the path to your DICOM file
dicom_file_path = r'E:\proje\data\0Hemmati\fMRI\MainData\2019_05_22\Image\Series4_ep2d_Run1/258'

# Load the DICOM file
dicom_dataset = pydicom.dcmread(dicom_file_path)

# Access the header information
header = dicom_dataset

# Print the header information
print(header)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 218
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.2.43.66088.2019052209322779581601616
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.6.0
# (0002, 0013) Implementation Version Name         SH: 'OFFIS_DCMTK_360'
# (0002, 0016) Source Application Entity Title     AE: 'MASTERGENTEST'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MOSAIC']
# (0008, 0012) Instance Creation Date              DA: '20190522'
# ...

# %%
#fumctional
import nibabel as nib

# Load the NIfTI file
nifti_path = r'E:\proje\data\0Hemmati\fMRI\MainData\2019_05_22\Image\Series6-ep2d_Run3\run3_1st_level\run3_tcontrasts/spmT_0001.nii'
nifti_img = nib.load(nifti_path)

# Get the image data array and dimensions
nifti_data = nifti_img.get_fdata()
dimensions = nifti_data.shape
# Get the voxel dimensions from the header
voxel_sizes = nifti_img.header.get_zooms()

# Print the voxel sizes along each axis
print("Voxel Size (X, Y, Z):", voxel_sizes)

print("Dimensions (X, Y, Z):", dimensions)
print("Number of voxels (X x Y x Z):", dimensions[0] * dimensions[1] * dimensions[2])

# %%
#t-contrast
import nibabel as nib

# Load the NIfTI file
nifti_path = r'E:\proje\data\0Hemmati\fMRI\MainData\2019_05_22\Image\Series4_ep2d_Run1\run1 nii/f97158030101-0003-00001-000001-01.nii'
nifti_img = nib.load(nifti_path)

# Get the image data array and dimensions
nifti_data = nifti_img.get_fdata()
dimensions = nifti_data.shape
# Get the voxel dimensions from the header
voxel_sizes = nifti_img.header.get_zooms()

# Print the voxel sizes along each axis
print("Voxel Size (X, Y, Z):", voxel_sizes)

print("Dimensions (X, Y, Z):", dimensions)
print("Number of voxels (X x Y x Z):", dimensions[0] * dimensions[1] * dimensions[2])
# Out:
# Voxel Size (X, Y, Z): (3.026316, 3.0263157, 3.6599998)
# Dimensions (X, Y, Z): (76, 76, 36)
# Number of voxels (X x Y x Z): 207936

# %%
#mask
import nibabel as nib

# Load the NIfTI file
nifti_path = "E:\\proje\\data\\0Hemmati\\fMRI\\MainData\\2019_05_22\\Image\\Series4_ep2d_Run1\\mask\\v1.nii"
nifti_img = nib.load(nifti_path)

# Get the image data array and dimensions
nifti_data = nifti_img.get_fdata()
dimensions = nifti_data.shape
# Get the voxel dimensions from the header
voxel_sizes = nifti_img.header.get_zooms()

# Print the voxel sizes along each axis
print("Voxel Size (X, Y, Z):", voxel_sizes)

print("Dimensions (X, Y, Z):", dimensions)
print("Number of voxels (X x Y x Z):", dimensions[0] * dimensions[1] * dimensions[2])
# Out:
# Voxel Size (X, Y, Z): (2.0, 2.0, 2.0)
# Dimensions (X, Y, Z): (91, 109, 91)
# Number of voxels (X x Y x Z): 902629

# %%
#structural
import nibabel as nib

# Load the NIfTI file
nifti_path = r'E:\proje\data\1Heydari\fMRI\MR\Series 2-t1_mprage_sag_p2_iso/anat nii/s97197041901-0002-00001-000160-01.nii'
nifti_img = nib.load(nifti_path)

# Get the image data array and dimensions
nifti_data = nifti_img.get_fdata()
dimensions = nifti_data.shape
# Get the voxel dimensions from the header
voxel_sizes = nifti_img.header.get_zooms()

# Print the voxel sizes along each axis
print("Voxel Size (X, Y, Z):", voxel_sizes)

print("Dimensions (X, Y, Z):", dimensions)
print("Number of voxels (X x Y x Z):", dimensions[0] * dimensions[1] * dimensions[2])
# Out:
# Voxel Size (X, Y, Z): (0.93750006, 0.9375, 0.90000004)
# Dimensions (X, Y, Z): (256, 256, 160)
# Number of voxels (X x Y x Z): 10485760

# %%
#mni
import nibabel as nib

# Load the NIfTI file
nifti_path = r'E:\proje\toolboxes\spm12\canonical/avg152pd.nii'
nifti_img = nib.load(nifti_path)

# Get the image data array and dimensions
nifti_data = nifti_img.get_fdata()
dimensions = nifti_data.shape
# Get the voxel dimensions from the header
voxel_sizes = nifti_img.header.get_zooms()

# Print the voxel sizes along each axis
print("Voxel Size (X, Y, Z):", voxel_sizes)


print("Dimensions (X, Y, Z):", dimensions)
print("Number of voxels (X x Y x Z):", dimensions[0] * dimensions[1] * dimensions[2])
# Out:
# Voxel Size (X, Y, Z): (2.0, 2.0, 2.0)
# Dimensions (X, Y, Z): (91, 109, 91)
# Number of voxels (X x Y x Z): 902629

# %%
import nibabel as nib

# Load the NIfTI file
nifti_img = nib.load(r'E:\proje\data\0Hemmati\fMRI\MainData\2019_05_22\Image\Series4_ep2d_Run1\run1 nii/arf97158030101-0003-00006-000006-01.nii')  # Replace 'your_fmri_file.nii.gz' with the path to your NIfTI file

# Get the header of the NIfTI file
header = nifti_img.header

# Get the slice timing information from the header
slice_timing = header.get_zooms()[2]  # Assuming slice timing is along the third axis

# Check if the slice timing is positive or negative
if slice_timing > 0:
    print("Odd slices are acquired first.")
else:
    print("Even slices are acquired first.")
# Out:
# Odd slices are acquired first.

# %%
slice_timing
# Out:
# 3.6599998
